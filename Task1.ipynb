# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushi240825/Task/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Example data
data = {'Gender': ['Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Other', 'Female', 'Male']}
df = pd.DataFrame(data)

# Count occurrences
gender_counts = df['Gender'].value_counts()

# Plot
sns.barplot(x=gender_counts.index, y=gender_counts.values)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
# Sample ages
df = pd.DataFrame({'Age': [23, 35, 45, 22, 36, 25, 55, 40, 30, 29, 60, 37, 41]})

# Plot
sns.histplot(df['Age'], bins=8, kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
